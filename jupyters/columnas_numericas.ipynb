# %% [markdown]
# # Análisis y gestión de nulos de las columnas numéricas

# %%
import pandas as pd
import numpy as np
import sys
sys.path.append("..")
from src import sp_visualizacion as vis
from src import sp_analisis as an

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x : '%.4f' % x)

# %%
# Leemos el archivo de datos limpio manteniendo el formato de fecha en las columnas date y dt_customer
df = pd.read_csv("../data/bank-customers-clean.csv", parse_dates=['date', 'dt_customer'])
df.head()
# Out:
#       age        job  marital    education default housing loan    contact  \
# 0     NaN  housemaid  married     basic.4y      no      no   no  telephone
# 1 57.0000   services  married  high.school     NaN      no   no  telephone
# 2 37.0000   services  married  high.school      no     yes   no  telephone
# 3 40.0000     admin.  married     basic.6y      no      no   no  telephone
# 4 56.0000   services  married  high.school      no      no  yes  telephone
#
#    campaign  pdays  previous     poutcome  emp_var_rate  cons_price_idx  \
# 0         1     -1         0  nonexistent        1.1000         93.9940
# 1         1     -1         0  nonexistent        1.1000         93.9940
# 2         1     -1         0  nonexistent        1.1000         93.9940
# 3         1     -1         0  nonexistent        1.1000         93.9940
# 4         1     -1         0  nonexistent        1.1000         93.9940
#
#    cons_conf_idx  euribor3m  nr_employed       date  \
# 0            -36     4.8570         5191 2019-08-02
# 1            -36        NaN         5191 2016-09-14
# 2            -36     4.8570         5191 2019-02-15
# 3            -36        NaN         5191 2015-11-29
# 4            -36        NaN         5191 2017-01-29
#
#                                      id  income  kidhome  teenhome  \
# 0  089b39d8-e4d0-461b-87d4-814d71e0e079  161770        1         0
# 1  e9d37224-cb6f-4942-98d7-46672963d097   85477        1         1
# 2  3f9f49b5-e410-4948-bf6e-f9244f04918b  147233        1         1
# 3  9991fafb-4447-451a-8be2-b0df6098d13e  121393        1         2
# 4  eca60b76-70b6-4077-80ba-bc52e8ebb0eb   63164        1         2
#
#   dt_customer  numwebvisitsmonth  contact_year  contact_month  customer_year  \
# 0  2012-04-04                 29     2019.0000         8.0000           2012
# 1  2012-12-30                  7     2016.0000         9.0000           2012
# 2  2012-02-02                  5     2019.0000         2.0000           2012
# 3  2012-12-21                 29     2015.0000        11.0000           2012
# 4  2012-06-20                 20     2017.0000         1.0000           2012
#
#    customer_month subscribed  duration_min
# 0               4         no        4.3500
# 1              12         no        2.4800
# 2               2         no        3.7700
# 3              12         no        2.5200
# 4               6         no        5.1200

# %%
#Seleccionamos las columnas numéricas
col_num = df.select_dtypes(include=np.number).columns.tolist()

# %% [markdown]
# ## Análisis de las columnas numéricas

# %%
df[col_num].describe().T
# Out:
#                        count       mean        std       min        25%  \
# age               37880.0000    39.9771    10.4380   17.0000    32.0000
# campaign          43000.0000     2.5672     2.7723    1.0000     1.0000
# pdays             43000.0000    -0.7388     1.5264   -1.0000    -1.0000
# previous          43000.0000     0.1740     0.4974    0.0000     0.0000
# emp_var_rate      43000.0000     0.0771     1.5739   -3.4000    -1.8000
# cons_price_idx    42529.0000    93.5742     0.5795   92.2010    93.0750
# cons_conf_idx     43000.0000   -40.1231     4.6673  -50.0000   -42.0000
# euribor3m         33744.0000     3.6165     1.7371    0.6340     1.3440
# nr_employed       43000.0000  5166.6659    72.4883 4963.0000  5099.0000
# income            43000.0000 93241.2001 50498.3162 5841.0000 49610.0000
# kidhome           43000.0000     1.0048     0.8159    0.0000     0.0000
# teenhome          43000.0000     0.9986     0.8160    0.0000     0.0000
# numwebvisitsmonth 43000.0000    16.5897     9.2392    1.0000     9.0000
# contact_year      42752.0000  2017.0013     1.4143 2015.0000  2016.0000
# contact_month     42752.0000     6.5021     3.4487    1.0000     4.0000
# customer_year     43000.0000  2012.8615     0.8795 2012.0000  2012.0000
# customer_month    43000.0000     6.5218     3.4471    1.0000     4.0000
# duration_min      43000.0000     4.2957     4.3111    0.0000     1.7000
#
#                          50%         75%         max
# age                  38.0000     47.0000     98.0000
# campaign              2.0000      3.0000     56.0000
# pdays                -1.0000     -1.0000     27.0000
# previous              0.0000      0.0000      7.0000
# emp_var_rate          1.1000      1.4000      1.4000
# cons_price_idx       93.7490     93.9940     94.7670
# cons_conf_idx       -41.0000    -36.0000    -26.0000
# euribor3m             4.8570      4.9610      5.0450
# nr_employed        5191.0000   5228.0000   5228.0000
# income            93050.5000 136744.5000 180802.0000
# kidhome               1.0000      2.0000      2.0000
# teenhome              1.0000      2.0000      2.0000
# numwebvisitsmonth    17.0000     25.0000     32.0000
# contact_year       2017.0000   2018.0000   2019.0000
# contact_month         7.0000     10.0000     12.0000
# customer_year      2013.0000   2014.0000   2014.0000
# customer_month        7.0000     10.0000     12.0000
# duration_min          2.9800      5.3200     81.9700

# %%
#Eliminamos las columnas numéricas relacionadas con las fechas
col_delete = ['contact_year', 'contact_month', 'customer_year','customer_month']
for col in col_delete:
    col_num.remove(col)

# %%
vis.subplot_col_num(df, col_num)

# %%
#Columnas con outliers
dict_outliers = {'age': 60,
                 'duration_min': 15,
                 'campaign': 6.5,
                 'previous': 0.5,
                 'cons_conf_idx': -28,
                 'pdays': -0.5}

# %%
for col, out in dict_outliers.items():
    outliers = df[col][df[col] > out].count()
    print (f'Para la columna {col.upper()} tenemos {outliers} outliers, lo que supone un {round(outliers/df.shape[0]*100, 3)}% de los datos')
# Out:
# Para la columna AGE tenemos 846 outliers, lo que supone un 1.967% de los datos
# Para la columna DURATION_MIN tenemos 1325 outliers, lo que supone un 3.081% de los datos
# Para la columna CAMPAIGN tenemos 2504 outliers, lo que supone un 5.823% de los datos
# Para la columna PREVIOUS tenemos 5897 outliers, lo que supone un 13.714% de los datos
# Para la columna CONS_CONF_IDX tenemos 477 outliers, lo que supone un 1.109% de los datos
# Para la columna PDAYS tenemos 1588 outliers, lo que supone un 3.693% de los datos

# %% [markdown]
# ## Análisis de las columnas de tipo fecha

# %%
col_date = ['contact_year', 'contact_month', 'customer_year','customer_month']

# %%
df[col_date].describe().T
# Out:
#                     count      mean    std       min       25%       50%  \
# contact_year   42752.0000 2017.0013 1.4143 2015.0000 2016.0000 2017.0000
# contact_month  42752.0000    6.5021 3.4487    1.0000    4.0000    7.0000
# customer_year  43000.0000 2012.8615 0.8795 2012.0000 2012.0000 2013.0000
# customer_month 43000.0000    6.5218 3.4471    1.0000    4.0000    7.0000
#
#                      75%       max
# contact_year   2018.0000 2019.0000
# contact_month    10.0000   12.0000
# customer_year  2014.0000 2014.0000
# customer_month   10.0000   12.0000

# %%
vis.subplot_col_num(df, col_date)

# %% [markdown]
# ## Gestión de nulos

# %%
df_num = df.select_dtypes(include=np.number).copy()
            
col_high_umbral, col_low_umbral = an.visualizar_nulos_numericos(df_num, umbral_pct_null=5)
# Out:
#           Columns DataType  Num_nulls  %_null  Change_value     Media  \
# 0             age  float64       5120 11.9070         False   39.9771
# 1  cons_price_idx  float64        471  1.0953          True   93.5742
# 2       euribor3m  float64       9256 21.5256         False    3.6165
# 3    contact_year  float64        248  0.5767          True 2017.0013
# 4   contact_month  float64        248  0.5767          True    6.5021
#
#     Mediana
# 0   38.0000
# 1   93.7490
# 2    4.8570
# 3 2017.0000
# 4    7.0000

# %% [markdown]
# ## Gestionamos nulos con porcentaje de nulos inferior al umbral
#    - El umbral establecido es 5%
#    - El método para rellenar los nulos va a ser fillna()

# %%
df_nulls = df.fillna(
    {
        "cons_price_idx": df["cons_price_idx"].mean(),
        "contact_year": df["contact_year"].median(),
        "contact_month": df["contact_month"].median() 
    }    
)

# %%
an.calcular_nulos(df_nulls[col_low_umbral])[0]
# Out:
# cons_price_idx    0
# contact_year      0
# contact_month     0
# dtype: int64

# %%
#Comprobamos como cambian los estadísticos al rellenar los nulos
#Describe del df nuevo
df_nulls[col_low_umbral].describe().T
# Out:
#                     count      mean    std       min       25%       50%  \
# cons_price_idx 43000.0000   93.5761 0.5767   92.2010   93.0750   93.7490
# contact_year   43000.0000 2017.0013 1.4102 2015.0000 2016.0000 2017.0000
# contact_month  43000.0000    6.5049 3.4390    1.0000    4.0000    7.0000
#
#                      75%       max
# cons_price_idx   93.9940   94.7670
# contact_year   2018.0000 2019.0000
# contact_month     9.0000   12.0000

# %%
#Describe del df con el que trabajo
df[col_low_umbral].describe().T
# Out:
#                     count      mean    std       min       25%       50%  \
# cons_price_idx 42529.0000   93.5742 0.5795   92.2010   93.0750   93.7490
# contact_year   42752.0000 2017.0013 1.4143 2015.0000 2016.0000 2017.0000
# contact_month  42752.0000    6.5021 3.4487    1.0000    4.0000    7.0000
#
#                      75%       max
# cons_price_idx   93.9940   94.7670
# contact_year   2018.0000 2019.0000
# contact_month    10.0000   12.0000

# %% [markdown]
# Comprobamos cambios mínimos en los estadísticos. Procedemos a gestionar los nulos de nuestro df, con el que estamos trabajando

# %%
df = df.fillna(
    {
        "cons_price_idx": df["cons_price_idx"].mean(),
        "contact_year": df["contact_year"].median(),
        "contact_month": df["contact_month"].median() 
    }    
)

# %%
df[col_low_umbral].describe().T
# Out:
#                     count      mean    std       min       25%       50%  \
# cons_price_idx 43000.0000   93.5761 0.5767   92.2010   93.0750   93.7490
# contact_year   43000.0000 2017.0013 1.4102 2015.0000 2016.0000 2017.0000
# contact_month  43000.0000    6.5049 3.4390    1.0000    4.0000    7.0000
#
#                      75%       max
# cons_price_idx   93.9940   94.7670
# contact_year   2018.0000 2019.0000
# contact_month     9.0000   12.0000

# %% [markdown]
# ## Gestionamos nulos con porcentaje de nulos superior al umbral
#    - El umbral establecido es 5%
#    - El método para rellenar los nulos va a ser iterativeimputer

# %%
df, col_iterative = an.imputar_iterative(df, col_high_umbral)
# Out:
#                          count    mean    std     min     25%     50%     75%  \
# age_iterative       43000.0000 39.9769 9.7969 17.0000 33.0000 39.8324 46.0000
# euribor3m_iterative 43000.0000  3.6165 1.5389  0.6340  1.4660  4.0760  4.9590
#
#                         max
# age_iterative       98.0000
# euribor3m_iterative  5.0450

# %%
df, col_knn = an.imputar_knn(df, col_high_umbral)
# Out:
#                    count    mean    std     min     25%     50%     75%  \
# age_knn       43000.0000 39.8851 9.9184 17.0000 32.0000 39.0000 46.0000
# euribor3m_knn 43000.0000  3.5937 1.5917  0.6340  1.4350  4.2088  4.9590
#
#                   max
# age_knn       98.0000
# euribor3m_knn  5.0450

# %%
df[col_high_umbral].describe().T
# Out:
#                count    mean     std     min     25%     50%     75%     max
# age       37880.0000 39.9771 10.4380 17.0000 32.0000 38.0000 47.0000 98.0000
# euribor3m 33744.0000  3.6165  1.7371  0.6340  1.3440  4.8570  4.9610  5.0450

# %%
col_imputadas = col_iterative + col_knn + col_high_umbral
df[col_imputadas].describe().sort_index(axis=1).T
# Out:
#                          count    mean     std     min     25%     50%  \
# age                 37880.0000 39.9771 10.4380 17.0000 32.0000 38.0000
# age_iterative       43000.0000 39.9769  9.7969 17.0000 33.0000 39.8324
# age_knn             43000.0000 39.8851  9.9184 17.0000 32.0000 39.0000
# euribor3m           33744.0000  3.6165  1.7371  0.6340  1.3440  4.8570
# euribor3m_iterative 43000.0000  3.6165  1.5389  0.6340  1.4660  4.0760
# euribor3m_knn       43000.0000  3.5937  1.5917  0.6340  1.4350  4.2088
#
#                         75%     max
# age                 47.0000 98.0000
# age_iterative       46.0000 98.0000
# age_knn             46.0000 98.0000
# euribor3m            4.9610  5.0450
# euribor3m_iterative  4.9590  5.0450
# euribor3m_knn        4.9590  5.0450

# %%
# Después de comprobar los estadísticos, eliminamos las columnas con nulos.
col_eliminar = col_iterative + col_high_umbral
df.drop(columns=col_eliminar, inplace = True)

# %%
#Guardamos avances
df.to_csv("../data/bank-customers-clean.csv", index=False)
