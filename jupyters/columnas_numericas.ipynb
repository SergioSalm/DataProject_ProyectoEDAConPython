# %%
import pandas as pd
import numpy as np
import sys
sys.path.append("..")
#from src import sp_analisis as an, sp_visualizacion as vis, sp_limpieza as lim
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x : '%.4f' % x)

# %%
# Leemos el archivo de datos limpio
df = pd.read_csv("../data/bank-customers.csv", parse_dates=['date', 'dt_customer'])
df.head()
# Out:
#       age        job  marital    education default housing loan    contact  \
# 0     NaN  housemaid  married     basic.4y      no      no   no  telephone
# 1 57.0000   services  married  high.school  unkown      no   no  telephone
# 2 37.0000   services  married  high.school      no     yes   no  telephone
# 3 40.0000     admin.  married     basic.6y      no      no   no  telephone
# 4 56.0000   services  married  high.school      no      no  yes  telephone
#
#    duration  campaign  pdays  previous     poutcome  emp_var_rate  \
# 0       261         1    999         0  nonexistent        1.1000
# 1       149         1    999         0  nonexistent        1.1000
# 2       226         1    999         0  nonexistent        1.1000
# 3       151         1    999         0  nonexistent        1.1000
# 4       307         1    999         0  nonexistent        1.1000
#
#    cons_price_idx  cons_conf_idx  euribor3m  nr_employed   y       date  \
# ...

# %%
col_num = df.select_dtypes(include=np.number).columns.tolist()
col_delete = ['year_bank', 'month_bank', 'year_customer','month_customer']
for col in col_delete:
    col_num.remove(col)
col_num
# Out:
# Index(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp_var_rate',
#        'cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed',
#        'latitude', 'longitude', 'income', 'kidhome', 'teenhome',
#        'numwebvisitsmonth', 'year_bank', 'month_bank', 'year_customer',
#        'month_customer'],
#       dtype='object')
