# %%
import pandas as pd
import sys
sys.path.append("..")
from src import sp_limpieza as sp
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/transformados/bank-customers-detail.csv')

# %%
df.shape
# Out:
# (43000, 28)

# %%
sp.eda_preliminar(df)
# Out:
#         age          job  marital          education  default  housing  loan  \
# 23465  36.0       admin.  MARRIED  university.degree      0.0      1.0   0.0
# 32661   NaN       admin.   SINGLE        high.school      0.0      0.0   0.0
# 9481   44.0  blue-collar   SINGLE           basic.4y      0.0      0.0   0.0
# 35478   NaN       admin.  MARRIED           basic.6y      0.0      1.0   0.0
# 17668   NaN          NaN  MARRIED                NaN      NaN      1.0   0.0
#
#          contact  duration  campaign  pdays  previous     poutcome  \
# 23465   cellular        86         5    999         0  NONEXISTENT
# 32661   cellular       610         2    999         0  NONEXISTENT
# 9481   telephone       128         1    999         0  NONEXISTENT
# 35478   cellular       170         1    999         0  NONEXISTENT
# 17668   cellular       112         1    999         0  NONEXISTENT
#
#        emp_var_rate cons_price_idx cons_conf_idx euribor3m nr_employed    y  \
# 23465           1.4         93,444         -36,1       NaN      5228,1   no
# 32661          -1.8         92,893         -46,2       NaN      5099,1  yes
# 9481            1.4         94,465         -41,8       NaN      5228,1   no
# 35478          -1.8         92,893         -46,2     1,244      5099,1   no
# 17668           1.4         93,918         -42,7       NaN      5228,1   no
#
#                     date  latitude  longitude  \
# 23465  24-noviembre-2017    26.229   -107.140
# 32661      16-junio-2019    33.267    -81.853
# 9481    6-noviembre-2018    33.342    -81.319
# 35478   4-noviembre-2017    42.664    -82.093
# 17668      25-marzo-2018    48.693    -72.215
#
#                                          id  income  kidhome  teenhome  \
# 23465  feb8c127-b1c4-488f-ac7b-7e981dad4684  179165        0         2
# 32661  23c2567a-6be1-4c20-8096-bb2eb9b08600  163932        2         2
# 9481   6c78c8ca-f4c2-4a0f-8d5f-3b6e12207bde   52445        0         2
# 35478  c4b14010-c4a9-42a6-9abd-29a059f8f6a0   45566        0         0
# 17668  fbface96-34b9-4047-ac56-a60227c7e980   27276        0         2
#
#       dt_customer  numwebvisitsmonth
# 23465  2013-10-20                  5
# 32661  2014-09-02                 13
# 9481   2012-02-01                 20
# 35478  2014-11-24                 30
# 17668  2012-04-13                 29
#                      count          mean           std       min          25%  \
# age                37880.0     39.977112     10.437957    17.000     32.00000
# default            34019.0      0.000088      0.009390     0.000      0.00000
# housing            41974.0      0.535998      0.498708     0.000      0.00000
# loan               41974.0      0.155620      0.362499     0.000      0.00000
# duration           43000.0    257.739279    258.666033     0.000    102.00000
# campaign           43000.0      2.567233      2.772294     1.000      1.00000
# pdays              43000.0    962.330953    187.260394     0.000    999.00000
# previous           43000.0      0.174023      0.497366     0.000      0.00000
# emp_var_rate       43000.0      0.077128      1.573898    -3.400     -1.80000
# latitude           43000.0     36.856697      7.225948    24.396     30.61475
# longitude          43000.0    -95.939067     16.752282  -124.997   -110.49425
# income             43000.0  93241.200070  50498.316182  5841.000  49610.00000
# kidhome            43000.0      1.004791      0.815913     0.000      0.00000
# teenhome           43000.0      0.998605      0.815983     0.000      0.00000
# numwebvisitsmonth  43000.0     16.589698      9.239205     1.000      9.00000
#
#                           50%           75%         max
# age                   38.0000      47.00000      98.000
# default                0.0000       0.00000       1.000
# housing                1.0000       1.00000       1.000
# loan                   0.0000       0.00000       1.000
# duration             179.0000     319.00000    4918.000
# campaign               2.0000       3.00000      56.000
# pdays                999.0000     999.00000     999.000
# previous               0.0000       0.00000       7.000
# emp_var_rate           1.1000       1.40000       1.400
# latitude              36.7610      43.11325      49.384
# longitude            -95.8995     -81.42775     -66.937
# income             93050.5000  136744.50000  180802.000
# kidhome                1.0000       2.00000       2.000
# teenhome               1.0000       2.00000       2.000
# numwebvisitsmonth     17.0000      25.00000      32.000
# ------------------------
# INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                37880 non-null  float64
#  1   job                42655 non-null  object
#  2   marital            42915 non-null  object
#  3   education          41193 non-null  object
#  4   default            34019 non-null  float64
#  5   housing            41974 non-null  float64
#  6   loan               41974 non-null  float64
#  7   contact            43000 non-null  object
#  8   duration           43000 non-null  int64
#  9   campaign           43000 non-null  int64
#  10  pdays              43000 non-null  int64
#  11  previous           43000 non-null  int64
#  12  poutcome           43000 non-null  object
#  13  emp_var_rate       43000 non-null  float64
#  14  cons_price_idx     42529 non-null  object
#  15  cons_conf_idx      43000 non-null  object
#  16  euribor3m          33744 non-null  object
#  17  nr_employed        43000 non-null  object
#  18  y                  43000 non-null  object
#  19  date               42752 non-null  object
#  20  latitude           43000 non-null  float64
#  21  longitude          43000 non-null  float64
#  22  id                 43000 non-null  object
#  23  income             43000 non-null  int64
#  24  kidhome            43000 non-null  int64
#  25  teenhome           43000 non-null  int64
#  26  dt_customer        43000 non-null  object
#  27  numwebvisitsmonth  43000 non-null  int64
# dtypes: float64(7), int64(8), object(13)
# memory usage: 9.2+ MB
# None
# ------------------------
# NULOS
# age                  11.91
# job                   0.80
# marital               0.20
# education             4.20
# default              20.89
# housing               2.39
# loan                  2.39
# contact               0.00
# duration              0.00
# campaign              0.00
# pdays                 0.00
# previous              0.00
# poutcome              0.00
# emp_var_rate          0.00
# cons_price_idx        1.10
# cons_conf_idx         0.00
# euribor3m            21.53
# nr_employed           0.00
# y                     0.00
# date                  0.58
# latitude              0.00
# longitude             0.00
# id                    0.00
# income                0.00
# kidhome               0.00
# teenhome              0.00
# dt_customer           0.00
# numwebvisitsmonth     0.00
# dtype: float64
# ------------------------
# DUPLICADOS
# np.int64(0)
# ------------------------
#                 count unique                                   top   freq
# job             42655     11                                admin.  10873
# marital         42915      3                               MARRIED  25999
# education       41193      7                     university.degree  12722
# contact         43000      2                              cellular  27396
# poutcome        43000      3                           NONEXISTENT  37103
# cons_price_idx  42529     26                                93,994   7938
# cons_conf_idx   43000     26                                 -36,4   8020
# euribor3m       33744    309                                 4,857   2287
# nr_employed     43000     11                                5228,1  16980
# y               43000      2                                    no  38156
# date            42752   1825                       28-febrero-2018     95
# id              43000  43000  993bbbd6-4dbc-4a40-a408-f91f8462bee6      1
# dt_customer     43000   1096                            2012-08-10     79
# VALUE COUNTS
# job
# admin.           10873
# blue-collar       9654
# technician        7026
# services          4162
# management        3050
# retired           1790
# entrepreneur      1522
# self-employed     1489
# housemaid         1123
# unemployed        1063
# student            903
# Name: count, dtype: int64
# ------------------
# marital
# MARRIED     25999
# SINGLE      12105
# DIVORCED     4811
# Name: count, dtype: int64
# ------------------
# education
# university.degree      12722
# high.school             9925
# basic.9y                6309
# professional.course     5477
# basic.4y                4356
# basic.6y                2386
# illiterate                18
# Name: count, dtype: int64
# ------------------
# contact
# cellular     27396
# telephone    15604
# Name: count, dtype: int64
# ------------------
# poutcome
# NONEXISTENT    37103
# FAILURE         4461
# SUCCESS         1436
# Name: count, dtype: int64
# ------------------
# cons_price_idx
# 93,994    7938
# 93,918    6937
# 92,893    5985
# 93,444    5349
# 94,465    4522
# 93,2      3731
# 93,075    2552
# 92,201     803
# 92,963     742
# 92,431     471
# 92,649     375
# 94,215     320
# 94,199     316
# 92,843     298
# 92,379     274
# 93,369     271
# 94,027     242
# 94,055     236
# 93,876     224
# 94,601     212
# 92,469     184
# 92,713     179
# 93,749     179
# 94,767     130
# 93,798      48
# 92,756      11
# Name: count, dtype: int64
# ------------------
# cons_conf_idx
# -36,4    8020
# -42,7    7004
# -46,2    6057
# -36,1    5408
# -41,8    4568
# -42      3782
# -47,1    2581
# -31,4     815
# -40,8     748
# -26,9     477
# -30,1     379
# -40,3     328
# -37,5     318
# -50       299
# -29,8     277
# -34,8     275
# -38,3     245
# -39,8     239
# -40       225
# -49,5     214
# -33,6     185
# -34,6     183
# -33       181
# -50,8     133
# -40,4      48
# -45,9      11
# Name: count, dtype: int64
# ------------------
# euribor3m
# 4,857    2287
# 4,962    2124
# 4,963    2019
# 4,961    1594
# 4,964     964
#          ...
# 5,045       1
# 4,921       1
# 0,895       1
# 0,956       1
# 0,953       1
# Name: count, Length: 309, dtype: int64
# ------------------
# nr_employed
# 5228,1    16980
# 5099,1     8937
# 5191       8020
# 5195,8     3830
# 5076,2     1748
# 5017,5     1133
# 4991,6      812
# 5008,7      683
# 4963,6      665
# 5023,5      181
# 5176,3       11
# Name: count, dtype: int64
# ------------------
# y
# no     38156
# yes     4844
# Name: count, dtype: int64
# ------------------
# date
# 28-febrero-2018      95
# 28-febrero-2016      94
# 28-febrero-2015      92
# 28-febrero-2017      89
# 28-febrero-2019      85
#                      ..
# 17-diciembre-2018    11
# 21-diciembre-2019    10
# 14-abril-2015        10
# 4-abril-2017         10
# 20-noviembre-2015    10
# Name: count, Length: 1825, dtype: int64
# ------------------
# id
# 993bbbd6-4dbc-4a40-a408-f91f8462bee6    1
# 089b39d8-e4d0-461b-87d4-814d71e0e079    1
# e9d37224-cb6f-4942-98d7-46672963d097    1
# 3f9f49b5-e410-4948-bf6e-f9244f04918b    1
# 9991fafb-4447-451a-8be2-b0df6098d13e    1
#                                        ..
# 66a752e2-b2f1-440c-9a8f-cc3b10d74dd0    1
# ca5c0d7a-8bbd-42b3-8351-1074c5be011a    1
# 8d700df5-0c33-4517-8cf8-92e1c92c9c12    1
# ea6b7d04-9271-4c0a-a01f-07795d164aba    1
# 87b79988-2be5-419d-88f4-56655852c565    1
# Name: count, Length: 43000, dtype: int64
# ------------------
# dt_customer
# 2012-08-10    79
# 2012-01-11    79
# 2012-12-28    75
# 2012-08-13    72
# 2012-12-21    72
#               ..
# 2013-09-09    15
# 2013-09-03    15
# 2013-02-26    15
# 2013-10-18    13
# 2013-10-24    12
# Name: count, Length: 1096, dtype: int64
# ------------------

# %% [markdown]
# # Transformación de datos

# %%
#Eliminamos las columnas 'latitude' y 'longitude'.
df.drop(columns=["latitude"], inplace=True)
df.drop(columns=["longitude"], inplace=True)

# %%
#pasamos todas las palabras a minúscula
sp.valores_minus(df)

# %%
df.sample()
# Out:
#         age        job  marital education  default  housing  loan   contact  \
# 39310  85.0  housemaid  married  basic.4y      NaN      0.0   0.0  cellular
#
#        duration  campaign  pdays  previous     poutcome  emp_var_rate  \
# 39310       166         1    999         0  nonexistent          -1.8
#
#       cons_price_idx cons_conf_idx euribor3m nr_employed   y  \
# 39310         93,749         -34,6     0,642      5008,7  no
#
#                    date                                    id  income  \
# 39310  8-noviembre-2018  0027ec1b-4474-4e44-87fd-8a58d6faf662  175534
#
#        kidhome  teenhome dt_customer  numwebvisitsmonth
# 39310        1         0  2014-09-24                 16

# %%
#Cambiamos los puntos por comas
col_comas = ['cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed']
sp.comas(df, col_comas)

# %%
df.sample()
# Out:
#         age      job marital          education  default  housing  loan  \
# 34331  23.0  student  single  university.degree      0.0      1.0   0.0
#
#         contact  duration  campaign  pdays  previous     poutcome  \
# 34331  cellular       200         1    999         0  nonexistent
#
#        emp_var_rate cons_price_idx cons_conf_idx euribor3m nr_employed   y  \
# 34331          -1.8         92.893         -46.2     1.266      5099.1  no
#
#                 date                                    id  income  kidhome  \
# 34331  28-julio-2018  2514be71-c4f7-4f62-8a9c-c9f93ada0b6a  130690        1
#
#        teenhome dt_customer  numwebvisitsmonth
# 34331         1  2014-03-27                 25

# %%
#Convertimos el mes de la columna date, que está como string y en español a número entero.
meses = {'enero':'01', 
         'febrero':'02', 
         'marzo':'03', 
         'abril':'04', 
         'mayo':'05', 
         'junio':'06', 
         'julio':'07', 
         'agosto':'08', 
         'septiembre':'09', 
         'octubre':'10', 
         'noviembre':'11', 
         'diciembre':'12', }

df.replace({'date':meses}, regex = True, inplace = True)

# %%
df.sample()
# Out:
#         age          job  marital education  default  housing  loan   contact  \
# 16049  49.0  blue-collar  married  basic.9y      NaN      0.0   0.0  cellular
#
#        duration  campaign  pdays  previous     poutcome  emp_var_rate  \
# 16049       270         2    999         0  nonexistent           1.4
#
#       cons_price_idx cons_conf_idx euribor3m nr_employed   y        date  \
# 16049         93.918         -42.7     4.961      5228.1  no  31-07-2017
#
#                                          id  income  kidhome  teenhome  \
# 16049  7a75ee98-1b6d-4284-82ea-404801c8039a  129680        1         1
#
#       dt_customer  numwebvisitsmonth
# 16049  2012-02-09                 17

# %%
#Convertimos columnas objet a dateTime con el formato de cada una
fecha_formato = {'date':'%d-%m-%Y',
                 'dt_customer':'%Y-%m-%d'}
sp.convertir_fechas(df, fecha_formato)

#Convertimos columnas objet a float o int
sp.convertir_enteros(df)

#Convertimos las columnas con 0,1, nan a 'Si', 'No', 'None'
bin_cols = ["default", "housing", "loan"]
sp.convertir_YesNo(df, bin_cols)

#Reemplazamos el valor 999 por -1 para tener los datos más agrupados
df["pdays"] = df["pdays"].replace(999, -1)

# %%
df.sample()
# Out:
#        age          job  marital education default housing loan   contact  \
# 28596  NaN  blue-collar  married  basic.9y      no     yes   no  cellular
#
#        duration  campaign  pdays  previous poutcome  emp_var_rate  \
# 28596       257         2     -1         1  failure          -1.8
#
#        cons_price_idx  cons_conf_idx  euribor3m  nr_employed   y       date  \
# 28596          93.075            -47       1.41         5099  no 2017-11-13
#
#                                          id  income  kidhome  teenhome  \
# 28596  21fa4d5b-e466-4d1d-aab5-234637ef22e0   59546        0         0
#
#       dt_customer  numwebvisitsmonth
# 28596  2013-01-21                  5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                37880 non-null  float64
#  1   job                42655 non-null  object
#  2   marital            42915 non-null  object
#  3   education          41193 non-null  object
#  4   default            43000 non-null  object
#  5   housing            43000 non-null  object
#  6   loan               43000 non-null  object
#  7   contact            43000 non-null  object
#  8   duration           43000 non-null  int64
#  9   campaign           43000 non-null  int64
#  10  pdays              43000 non-null  int64
#  11  previous           43000 non-null  int64
#  12  poutcome           43000 non-null  object
#  13  emp_var_rate       43000 non-null  float64
#  14  cons_price_idx     42529 non-null  float64
#  15  cons_conf_idx      43000 non-null  int64
#  16  euribor3m          33744 non-null  float64
#  17  nr_employed        43000 non-null  int64
#  18  y                  43000 non-null  object
#  19  date               42752 non-null  datetime64[ns]
#  20  id                 43000 non-null  object
#  21  income             43000 non-null  int64
#  22  kidhome            43000 non-null  int64
#  23  teenhome           43000 non-null  int64
#  24  dt_customer        43000 non-null  datetime64[ns]
#  25  numwebvisitsmonth  43000 non-null  int64
# dtypes: datetime64[ns](2), float64(4), int64(10), object(10)
# memory usage: 8.5+ MB

# %% [markdown]
# # Creamos columnas

# %%
#Creamos campos de año y mes para la columna date
df['contact_year'] = df['date'].dt.year
df['contact_month'] = df['date'].dt.month

#Creamos campos de año y mes para la columna dt_customer
df['customer_year'] = df['dt_customer'].dt.year
df['customer_month'] = df['dt_customer'].dt.month

#Creamos una columna nueva para tener un título más aclarativo y borramos la original
df["subscribed"] = df["y"]
df.drop(columns=["y"], inplace=True)

#Creamos la columna duration_min y eliminanos la columna duration
df["duration_min"] = (df["duration"] / 60).round(2)
df.drop(columns=["duration"], inplace=True)

#Creamos una columna have_children para agrupar Kidhome y Teenhome, y eliminamos estas dos últimas
df["have_children"] = ((df["kidhome"] > 0) | (df["teenhome"] > 0)).astype(int)
df.drop(columns=["kidhome"], inplace=True)
df.drop(columns=["teenhome"], inplace=True)

sp.convertir_YesNo(df, ["have_children"])

#Creamos la columna income_type_income para diferenciar los ingresos en 3 tipos: low, high, superior
#Hasta 70.000 consideramos 'low'. De 70.001 a 140.000 consideramos 'high' y a partir de 140.001, son 'superior'
sp.clasificar_valores(df, 'income', 'income_type', [-1, 70000, 140000, float('inf')], ['low', 'high', 'superior'])
df.drop(columns=["income"], inplace=True)

# %%
df.sample()
# Out:
#         age         job  marital          education default housing loan  \
# 20835  31.0  technician  married  university.degree      no     yes   no
#
#         contact  campaign  pdays  previous     poutcome  emp_var_rate  \
# 20835  cellular         1     -1         0  nonexistent           1.4
#
#        cons_price_idx  cons_conf_idx  euribor3m  nr_employed       date  \
# 20835          93.444            -36      4.964         5228 2016-03-06
#
#                                          id dt_customer  numwebvisitsmonth  \
# 20835  75e0cca4-24f2-4841-8e90-a8ad014efd34  2013-05-09                 25
#
#        contact_year  contact_month  customer_year  customer_month subscribed  \
# 20835        2016.0            3.0           2013               5         no
#
#        duration_min have_children income_type
# 20835          1.58           yes         low

# %%
df.to_csv("../data/data-clean.csv", index=False)
